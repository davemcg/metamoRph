# %%
import cellxgene_census
import pandas as pd

# %%
with cellxgene_census.open_soma() as census:
    
    # Reads SOMADataFrame as a slice
    cell_metadata = census["census_data"]["homo_sapiens"].obs.read(
        value_filter = "tissue_general in ['eye'] "
        "and disease == 'normal' "
        "and is_primary_data == True"

    )
    
    # Concatenates results to pyarrow.Table
    cell_metadata = cell_metadata.concat()
    
    # Converts to pandas.DataFrame
    cell_metadata = cell_metadata.to_pandas()
    
    print(cell_metadata)
# Out:
# The "stable" Census version is not yet available. Using "latest" Census version instead.
# The "latest" release is currently 2023-05-08. Specify 'census_version="2023-05-08"' in future calls to open_soma() to ensure data consistency.
#         soma_joinid                            dataset_id          assay
# 0           6870420  f8c77961-67a7-4161-b8c2-61c3f917b54f      10x 3' v3  \
# 1           6870421  f8c77961-67a7-4161-b8c2-61c3f917b54f      10x 3' v3
# 2           6870422  f8c77961-67a7-4161-b8c2-61c3f917b54f      10x 3' v3
# 3           6870423  f8c77961-67a7-4161-b8c2-61c3f917b54f      10x 3' v3
# 4           6870424  f8c77961-67a7-4161-b8c2-61c3f917b54f      10x 3' v3
# ...             ...                                   ...            ...
# 755159     50130808  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 755160     50130809  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 755161     50130810  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 755162     50130811  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 755163     50130812  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
#
#        assay_ontology_term_id      cell_type cell_type_ontology_term_id
# 0                 EFO:0009922  amacrine cell                 CL:0000561  \
# 1                 EFO:0009922  amacrine cell                 CL:0000561
# 2                 EFO:0009922  amacrine cell                 CL:0000561
# 3                 EFO:0009922  amacrine cell                 CL:0000561
# 4                 EFO:0009922  amacrine cell                 CL:0000561
# ...                       ...            ...                        ...
# 755159            EFO:0030002         neuron                 CL:0000540
# 755160            EFO:0030002         neuron                 CL:0000540
# 755161            EFO:0030002         neuron                 CL:0000540
# 755162            EFO:0030002         neuron                 CL:0000540
# 755163            EFO:0030002         neuron                 CL:0000540
#
#                                development_stage
# 0                        77-year-old human stage  \
# 1                        77-year-old human stage
# 2                        77-year-old human stage
# 3                        77-year-old human stage
# 4                        77-year-old human stage
# ...                                          ...
# 755159  11th week post-fertilization human stage
# 755160  11th week post-fertilization human stage
# 755161  11th week post-fertilization human stage
# 755162  11th week post-fertilization human stage
# 755163  11th week post-fertilization human stage
#
#        development_stage_ontology_term_id disease disease_ontology_term_id
# 0                          HsapDv:0000171  normal             PATO:0000461  \
# 1                          HsapDv:0000171  normal             PATO:0000461
# 2                          HsapDv:0000171  normal             PATO:0000461
# 3                          HsapDv:0000171  normal             PATO:0000461
# 4                          HsapDv:0000171  normal             PATO:0000461
# ...                                   ...     ...                      ...
# 755159                     HsapDv:0000048  normal             PATO:0000461
# 755160                     HsapDv:0000048  normal             PATO:0000461
# 755161                     HsapDv:0000048  normal             PATO:0000461
# 755162                     HsapDv:0000048  normal             PATO:0000461
# 755163                     HsapDv:0000048  normal             PATO:0000461
#
#         ... is_primary_data  self_reported_ethnicity
# 0       ...            True                  unknown  \
# 1       ...            True                  unknown
# 2       ...            True                  unknown
# 3       ...            True                  unknown
# 4       ...            True                  unknown
# ...     ...             ...                      ...
# 755159  ...            True              Han Chinese
# 755160  ...            True              Han Chinese
# 755161  ...            True              Han Chinese
# 755162  ...            True              Han Chinese
# 755163  ...            True              Han Chinese
#
#        self_reported_ethnicity_ontology_term_id     sex sex_ontology_term_id
# 0                                       unknown  female         PATO:0000383  \
# 1                                       unknown  female         PATO:0000383
# 2                                       unknown  female         PATO:0000383
# 3                                       unknown  female         PATO:0000383
# 4                                       unknown  female         PATO:0000383
# ...                                         ...     ...                  ...
# 755159                           HANCESTRO:0027  female         PATO:0000383
# 755160                           HANCESTRO:0027  female         PATO:0000383
# 755161                           HANCESTRO:0027  female         PATO:0000383
# 755162                           HANCESTRO:0027  female         PATO:0000383
# 755163                           HANCESTRO:0027  female         PATO:0000383
#
#        suspension_type  tissue tissue_ontology_term_id tissue_general
# 0              nucleus  retina          UBERON:0000966            eye  \
# 1              nucleus  retina          UBERON:0000966            eye
# 2              nucleus  retina          UBERON:0000966            eye
# 3              nucleus  retina          UBERON:0000966            eye
# 4              nucleus  retina          UBERON:0000966            eye
# ...                ...     ...                     ...            ...
# 755159            cell     eye          UBERON:0000970            eye
# 755160            cell     eye          UBERON:0000970            eye
# 755161            cell     eye          UBERON:0000970            eye
# 755162            cell     eye          UBERON:0000970            eye
# 755163            cell     eye          UBERON:0000970            eye
#
#        tissue_general_ontology_term_id
# 0                       UBERON:0000970
# 1                       UBERON:0000970
# 2                       UBERON:0000970
# 3                       UBERON:0000970
# 4                       UBERON:0000970
# ...                                ...
# 755159                  UBERON:0000970
# 755160                  UBERON:0000970
# 755161                  UBERON:0000970
# 755162                  UBERON:0000970
# 755163                  UBERON:0000970
#
# [755164 rows x 21 columns]

# %%
for i in list(set(cell_metadata['dataset_id'])):
    print(i)
    print(cell_metadata[cell_metadata['dataset_id'] == i]['cell_type'].value_counts())
    print('\n\n')
# Out:
# 53d208b0-2cfd-4366-9866-c3c6114081bc
# cell_type
# conjunctival epithelial cell             4587
# corneal epithelial cell                  1488
# eye photoreceptor cell                    891
# keratocyte                                595
# retinal blood vessel endothelial cell     466
# Mueller cell                              360
# stromal cell                              325
# T cell                                    237
# microglial cell                           209
# radial glial cell                         195
# dendritic cell                            182
# melanocyte                                144
# stem cell                                 144
# macrophage                                108
# endothelial cell                          105
# B cell                                    102
# fibroblast                                 95
# surface ectodermal cell                    54
# epithelial cell of lacrimal sac            52
# retinal pigment epithelial cell            49
# plasma cell                                46
# monocyte                                   44
# fat cell                                   44
# retinal bipolar neuron                     34
# erythroid lineage cell                     30
# CD4-positive, alpha-beta T cell            23
# pigmented ciliary epithelial cell          17
# CD8-positive, alpha-beta T cell             8
# retina horizontal cell                      6
# mast cell                                   5
# retinal ganglion cell                       5
# Name: count, dtype: int64
#
#
#
# cec9f9a5-8832-437d-99af-fb8237cde54b
# cell_type
# retinal ganglion cell    1757
# native cell                20
# Name: count, dtype: int64
#
#
#
# 9ff99bf8-2524-4ab5-ab6e-4bc218e4a449
# cell_type
# fibroblast                                  7523
# basal cell                                  4164
# melanocyte                                  4158
# corneal epithelial cell                     3920
# Schwann cell                                3180
# ciliary muscle cell                         2933
# macrophage                                  2933
# pigmented epithelial cell                   2000
# corneal endothelial cell                    1926
# conjunctival epithelial cell                1703
# endothelial cell                            1463
# pigmented ciliary epithelial cell            998
# endothelial cell of lymphatic vessel         997
# non-pigmented ciliary epithelial cell        997
# lymphocyte                                   993
# smooth muscle cell of sphincter of pupil     935
# pericyte                                     587
# blood vessel endothelial cell                586
# transit amplifying cell                      374
# goblet cell                                  293
# leukocyte                                    192
# mast cell                                     46
# Name: count, dtype: int64
#
#
#
# ccfdcad0-7104-46b9-addf-fd66a2a15907
# cell_type
# retinal rod cell                     13029
# Mueller cell                          8207
# rod bipolar cell                      4191
# ON-bipolar cell                       2130
# OFF-bipolar cell                      1470
# fibroblast                            1355
# retinal cone cell                     1202
# retina horizontal cell                 844
# amacrine cell                          747
# monocyte                               300
# endothelial cell of vascular tree      208
# retinal pigment epithelial cell        186
# astrocyte                              172
# microglial cell                        171
# T cell                                 160
# melanocyte                             157
# pericyte                                85
# natural killer cell                     44
# retinal ganglion cell                   35
# mast cell                               30
# Name: count, dtype: int64
#
#
#
# e6dad530-418b-47f9-af6e-472e56a7b314
# cell_type
# retinal rod cell                   62523
# retinal bipolar neuron             16695
# amacrine cell                       6317
# Mueller cell                        5114
# retinal ganglion cell               2433
# retina horizontal cell              1913
# retinal cone cell                   1777
# retinal pigment epithelial cell     1704
# native cell                          612
# astrocyte                            574
# myeloid cell                         393
# Name: count, dtype: int64
#
#
#
# d95ab381-2b7c-4885-b168-0097ed4e397f
# cell_type
# retinal cone cell    1230
# native cell           148
# Name: count, dtype: int64
#
#
#
# d319af7f-be2e-441e-8caa-3b8a88480e89
# cell_type
# retinal ganglion cell    11404
# Name: count, dtype: int64
#
#
#
# babbf9f3-f482-45a5-ba76-c41f4c2f503e
# cell_type
# retinal ganglion cell                6086
# Mueller cell                         3886
# OFF-bipolar cell                     2456
# retinal rod cell                     1894
# retinal cone cell                    1375
# retina horizontal cell               1037
# rod bipolar cell                     1016
# endothelial cell of vascular tree     368
# amacrine cell                         315
# T cell                                299
# fibroblast                            252
# microglial cell                       172
# astrocyte                             149
# monocyte                              137
# natural killer cell                   130
# retinal pigment epithelial cell        84
# pericyte                               75
# B cell                                 37
# Name: count, dtype: int64
#
#
#
# 2adb1f8a-a6b1-4909-8ee8-484814e2d4bf
# cell_type
# neuron                                  804
# mesenchymal stem cell                   401
# epithelial cell                         256
# erythroid lineage cell                  228
# primordial germ cell                     58
# endothelial cell                         44
# cell of skeletal muscle                  24
# stromal cell                             19
# fibroblast                               14
# erythroid progenitor cell                 6
# professional antigen presenting cell      6
# dendritic cell                            5
# endocrine cell                            4
# macrophage                                3
# T cell                                    2
# basal cell                                2
# embryonic stem cell                       1
# cord blood hematopoietic stem cell        1
# stratified epithelial cell                1
# goblet cell                               1
# Name: count, dtype: int64
#
#
#
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353
# cell_type
# Mueller cell                         14865
# photoreceptor cell                   12398
# retinal ganglion cell                 8745
# amacrine cell                         8147
# retina horizontal cell                2300
# ganglion interneuron                  1398
# bipolar neuron                        1207
# stromal cell                          1049
# retinal pigment epithelial cell        704
# lens fiber cell                        246
# endothelial cell of vascular tree      211
# astrocyte                              181
# cell of skeletal muscle                148
# corneal epithelial cell                104
# microglial cell                         88
# smooth muscle cell                      45
# Name: count, dtype: int64
#
#
#
# 0129dbd9-a7d3-4f6b-96b9-1da155a93748
# cell_type
# retinal rod cell          97939
# amacrine cell             56507
# retinal bipolar neuron    53040
# glial cell                18011
# retinal cone cell         11629
# retina horizontal cell     7348
# Name: count, dtype: int64
#
#
#
# f8c77961-67a7-4161-b8c2-61c3f917b54f
# cell_type
# amacrine cell    6101
# Name: count, dtype: int64
#
#
#
# 5cdbb2ea-c622-466d-9ead-7884ad8cb99f
# cell_type
# amacrine cell         7542
# glycinergic neuron    6065
# Name: count, dtype: int64
#
#
#
# d5c67a4e-a8d9-456d-a273-fa01adb1b308
# cell_type
# retinal rod cell         11187
# native cell               3468
# ON-bipolar cell           1303
# Mueller cell               513
# retinal cone cell          507
# OFF-bipolar cell           479
# amacrine cell              238
# microglial cell            132
# retinal ganglion cell       57
# Name: count, dtype: int64
#
#
#
# 489318a0-24c3-4f5c-b105-f084ed0ea026
# cell_type
# anterior lens cell      6160
# lens epithelial cell    5276
# secondary lens fiber    1677
# lens fiber cell          787
# Name: count, dtype: int64
#
#
#
# 9cfee1e6-b24f-433d-a269-f01841655d6a
# cell_type
# retinal pigment epithelial cell    1635
# Name: count, dtype: int64
#
#
#
# aad97cb5-f375-45ef-ae9d-178e7f5d5180
# cell_type
# retinal ganglion cell    11617
# Name: count, dtype: int64
#
#
#
# 7b75b2c4-6d99-40be-9a61-391455d859e6
# cell_type
# retinal rod cell     7073
# retinal cone cell    1997
# Name: count, dtype: int64
#
#
#
# de17ac25-550a-4018-be75-bbb485a0636e
# cell_type
# myeloid cell    395
# Name: count, dtype: int64
#
#
#
# 4e38f019-f8e8-44ae-ad32-ba500de6f64c
# cell_type
# ON-bipolar cell     10621
# OFF-bipolar cell     5919
# Name: count, dtype: int64
#
#
#
# 389bfbb9-8ef1-4582-8c41-410131c3d0eb
# cell_type
# retinal rod cell    62509
# Name: count, dtype: int64
#
#
#
# 2f6a20f1-173d-4b8d-860b-c47ffea120fa
# cell_type
# retina horizontal cell    2868
# Name: count, dtype: int64
#
#
#
# c3d381b2-3104-444e-8ad5-d3524407bbb6
# cell_type
# retina horizontal cell    1834
# native cell                 41
# Name: count, dtype: int64
#
#
#
# 8623d55f-d91c-41c2-ae68-ed2072fd268d
# cell_type
# ON-bipolar cell     14803
# OFF-bipolar cell    11105
# Name: count, dtype: int64
#
#
#
# ab5b2256-b209-48b5-a801-c5d9a8c0de56
# cell_type
# Mueller cell                       5024
# retinal pigment epithelial cell    1643
# astrocyte                           508
# myeloid cell                        395
# pericyte                            188
# melanocyte                          186
# T cell                               87
# endothelial cell                     50
# Schwann cell                         44
# B cell                               41
# native cell                          27
# Name: count, dtype: int64
#
#
#
# bc7260e0-54cf-4b0b-823d-93f5b850f757
# cell_type
# Mueller cell        19896
# astrocyte            1149
# microglial cell       671
# endothelial cell      409
# Name: count, dtype: int64
#
#
#
# 856c1b98-5727-49da-bf0f-151bdb8cb056
# cell_type
# retinal rod cell                         9145
# macroglial cell                          5276
# retinal bipolar neuron                   3155
# retinal ganglion cell                    1514
# amacrine cell                             497
# retinal cone cell                         211
# retina horizontal cell                    146
# retinal blood vessel endothelial cell      85
# microglial cell                            62
# Name: count, dtype: int64

# %%
# pull doi
doi_uniq = []
for i in cell_metadata['dataset_id']:
    doi_uniq.append(i)
doi_uniq = list(set(doi_uniq))

# %%
census_datasets = census["census_info"]["datasets"].read().concat().to_pandas()
census_datasets = census_datasets.set_index("soma_joinid")
eye_sets = census_datasets[census_datasets['dataset_id'].isin(doi_uniq)]

# %%
set(eye_sets['collection_doi'].tolist())
# Out:
# {'10.1016/j.cell.2020.08.013',
#  '10.1016/j.celrep.2019.12.082',
#  '10.1038/s41467-019-12780-8',
#  '10.1038/s41586-020-2157-4',
#  '10.1038/s41598-020-66092-9',
#  '10.1073/pnas.2200914119',
#  '10.1126/science.aba7721',
#  '10.1126/science.abl4896',
#  '10.15252/embj.2018100811',
#  '10.2139/ssrn.3991078'}

# %%
from habanero import Crossref
cr = Crossref()

# %%
for doi in set(eye_sets['collection_doi'].tolist()):
    ref = cr.works(ids = doi)
    print(doi)
    print(eye_sets[eye_sets['collection_doi'] == doi]['dataset_id'])
    print(ref['message']['title'])
    print(ref['message']['author'][0])
    print('\n')
# Out:
# 10.1038/s41586-020-2157-4
# soma_joinid
# 546    2adb1f8a-a6b1-4909-8ee8-484814e2d4bf
# Name: dataset_id, dtype: object
# ['Construction of a human cell landscape at single-cell level']
# {'given': 'Xiaoping', 'family': 'Han', 'sequence': 'first', 'affiliation': []}
#
#
# 10.1073/pnas.2200914119
# soma_joinid
# 62    9ff99bf8-2524-4ab5-ab6e-4bc218e4a449
# 64    489318a0-24c3-4f5c-b105-f084ed0ea026
# Name: dataset_id, dtype: object
# ['Cell atlas of the human ocular anterior segment: Tissue-specific and shared cell types']
# {'given': 'Tavé', 'family': 'van Zyl', 'sequence': 'first', 'affiliation': [{'name': 'Department of Ophthalmology, Harvard Medical School, Boston, MA 02115'}, {'name': 'Center for Brain Science, Harvard University, Cambridge, MA 02138'}, {'name': 'Department of Molecular and Cellular Biology, Harvard University, Cambridge, MA 02138'}]}
#
#
# 10.15252/embj.2018100811
# soma_joinid
# 368    d5c67a4e-a8d9-456d-a273-fa01adb1b308
# Name: dataset_id, dtype: object
# ['A single‐cell transcriptome atlas of the adult human retina']
# {'ORCID': 'http://orcid.org/0000-0002-8598-7902', 'authenticated-orcid': False, 'given': 'Samuel W', 'family': 'Lukowski', 'sequence': 'first', 'affiliation': [{'name': 'Institute for Molecular Bioscience University of Queensland Brisbane Qld Australia'}]}
#
#
# 10.1016/j.celrep.2019.12.082
# soma_joinid
# 35    f8c77961-67a7-4161-b8c2-61c3f917b54f
# 36    e6dad530-418b-47f9-af6e-472e56a7b314
# 37    de17ac25-550a-4018-be75-bbb485a0636e
# 38    d95ab381-2b7c-4885-b168-0097ed4e397f
# 39    cec9f9a5-8832-437d-99af-fb8237cde54b
# 40    c3d381b2-3104-444e-8ad5-d3524407bbb6
# 41    ab5b2256-b209-48b5-a801-c5d9a8c0de56
# 42    9cfee1e6-b24f-433d-a269-f01841655d6a
# 43    4e38f019-f8e8-44ae-ad32-ba500de6f64c
# 44    389bfbb9-8ef1-4582-8c41-410131c3d0eb
# Name: dataset_id, dtype: object
# ['Integration of eQTL and a Single-Cell Atlas in the Human Eye Identifies Causal Genes for Age-Related Macular Degeneration']
# {'given': 'Luz D.', 'family': 'Orozco', 'sequence': 'first', 'affiliation': []}
#
#
# 10.1126/science.abl4896
# soma_joinid
# 431    53d208b0-2cfd-4366-9866-c3c6114081bc
# Name: dataset_id, dtype: object
# ['The Tabula Sapiens: A multiple-organ, single-cell transcriptomic atlas of humans']
# {'name': 'The Tabula Sapiens Consortium*', 'sequence': 'first', 'affiliation': []}
#
#
# 10.1038/s41467-019-12780-8
# soma_joinid
# 243    856c1b98-5727-49da-bf0f-151bdb8cb056
# Name: dataset_id, dtype: object
# ['Single-cell transcriptomic atlas of the human retina identifies cell types associated with age-related macular degeneration']
# {'given': 'Madhvi', 'family': 'Menon', 'sequence': 'first', 'affiliation': []}
#
#
# 10.1126/science.aba7721
# soma_joinid
# 439    f7c1c579-2dc0-47e2-ba19-8165c5a0e353
# Name: dataset_id, dtype: object
# ['A human cell atlas of fetal gene expression']
# {'ORCID': 'http://orcid.org/0000-0003-4097-489X', 'authenticated-orcid': True, 'given': 'Junyue', 'family': 'Cao', 'sequence': 'first', 'affiliation': [{'name': 'Department of Genome Sciences, University of Washington School of Medicine, Seattle, WA, USA.'}]}
#
#
# 10.1038/s41598-020-66092-9
# soma_joinid
# 66    d319af7f-be2e-441e-8caa-3b8a88480e89
# 67    bc7260e0-54cf-4b0b-823d-93f5b850f757
# 68    8623d55f-d91c-41c2-ae68-ed2072fd268d
# 69    7b75b2c4-6d99-40be-9a61-391455d859e6
# 70    5cdbb2ea-c622-466d-9ead-7884ad8cb99f
# 71    2f6a20f1-173d-4b8d-860b-c47ffea120fa
# Name: dataset_id, dtype: object
# ['Cell Atlas of The Human Fovea and Peripheral Retina']
# {'given': 'Wenjun', 'family': 'Yan', 'sequence': 'first', 'affiliation': []}
#
#
# 10.1016/j.cell.2020.08.013
# soma_joinid
# 309    ccfdcad0-7104-46b9-addf-fd66a2a15907
# 310    babbf9f3-f482-45a5-ba76-c41f4c2f503e
# Name: dataset_id, dtype: object
# ['Cell Types of the Human Retina and Its Organoids at Single-Cell Resolution']
# {'given': 'Cameron S.', 'family': 'Cowan', 'sequence': 'first', 'affiliation': []}
#
#
# 10.2139/ssrn.3991078
# soma_joinid
# 404    0129dbd9-a7d3-4f6b-96b9-1da155a93748
# 406    aad97cb5-f375-45ef-ae9d-178e7f5d5180
# Name: dataset_id, dtype: object
# ['A Multi-Omics Atlas of the Human Retina at Single-Cell Resolution']
# {'given': 'Qingnan', 'family': 'Liang', 'sequence': 'first', 'affiliation': []}

# %%
eye_sets
# Out:
#                                     collection_id
# soma_joinid
# 35           939769a8-d8d2-4d01-abfc-55699893fd49  \
# 36           939769a8-d8d2-4d01-abfc-55699893fd49
# 37           939769a8-d8d2-4d01-abfc-55699893fd49
# 38           939769a8-d8d2-4d01-abfc-55699893fd49
# 39           939769a8-d8d2-4d01-abfc-55699893fd49
# 40           939769a8-d8d2-4d01-abfc-55699893fd49
# 41           939769a8-d8d2-4d01-abfc-55699893fd49
# 42           939769a8-d8d2-4d01-abfc-55699893fd49
# 43           939769a8-d8d2-4d01-abfc-55699893fd49
# 44           939769a8-d8d2-4d01-abfc-55699893fd49
# 62           63d03351-06be-478e-a0db-f7a653b6b19b
# 64           63d03351-06be-478e-a0db-f7a653b6b19b
# 66           1d1c7275-476a-49e2-9022-ad1b1c793594
# 67           1d1c7275-476a-49e2-9022-ad1b1c793594
# 68           1d1c7275-476a-49e2-9022-ad1b1c793594
# 69           1d1c7275-476a-49e2-9022-ad1b1c793594
# 70           1d1c7275-476a-49e2-9022-ad1b1c793594
# 71           1d1c7275-476a-49e2-9022-ad1b1c793594
# 243          1a486c4c-c115-4721-8c9f-f9f096e10857
# 309          2f4c738f-e2f3-4553-9db2-0582a38ea4dc
# 310          2f4c738f-e2f3-4553-9db2-0582a38ea4dc
# 368          3472f32d-4a33-48e2-aad5-666d4631bf4c
# 404          af893e86-8e9f-41f1-a474-ef05359b1fb7
# 406          af893e86-8e9f-41f1-a474-ef05359b1fb7
# 431          e5f58829-1a66-40b5-a624-9046778e74f5
# 439          c114c20f-1ef4-49a5-9c2e-d965787fb90c
# 546          38833785-fac5-48fd-944a-0f62a4c23ed1
#
#                                                collection_name
# soma_joinid
# 35           Integration of eQTL and a Single-Cell Atlas in...  \
# 36           Integration of eQTL and a Single-Cell Atlas in...
# 37           Integration of eQTL and a Single-Cell Atlas in...
# 38           Integration of eQTL and a Single-Cell Atlas in...
# 39           Integration of eQTL and a Single-Cell Atlas in...
# 40           Integration of eQTL and a Single-Cell Atlas in...
# 41           Integration of eQTL and a Single-Cell Atlas in...
# 42           Integration of eQTL and a Single-Cell Atlas in...
# 43           Integration of eQTL and a Single-Cell Atlas in...
# 44           Integration of eQTL and a Single-Cell Atlas in...
# 62           Cell atlas of the human ocular anterior segmen...
# 64           Cell atlas of the human ocular anterior segmen...
# 66           Cell Atlas of The Human Fovea and Peripheral R...
# 67           Cell Atlas of The Human Fovea and Peripheral R...
# 68           Cell Atlas of The Human Fovea and Peripheral R...
# 69           Cell Atlas of The Human Fovea and Peripheral R...
# 70           Cell Atlas of The Human Fovea and Peripheral R...
# 71           Cell Atlas of The Human Fovea and Peripheral R...
# 243          Single-cell transcriptomic atlas of the human ...
# 309          Cell Types of the Human Retina and Its Organoi...
# 310          Cell Types of the Human Retina and Its Organoi...
# 368          A single-cell transcriptome atlas of the adult...
# 404          Single-cell transcriptomic atlas for adult hum...
# 406          Single-cell transcriptomic atlas for adult hum...
# 431                                             Tabula Sapiens
# 439                A human cell atlas of fetal gene expression
# 546          Construction of a human cell landscape at sing...
#
#                            collection_doi
# soma_joinid
# 35           10.1016/j.celrep.2019.12.082  \
# 36           10.1016/j.celrep.2019.12.082
# 37           10.1016/j.celrep.2019.12.082
# 38           10.1016/j.celrep.2019.12.082
# 39           10.1016/j.celrep.2019.12.082
# 40           10.1016/j.celrep.2019.12.082
# 41           10.1016/j.celrep.2019.12.082
# 42           10.1016/j.celrep.2019.12.082
# 43           10.1016/j.celrep.2019.12.082
# 44           10.1016/j.celrep.2019.12.082
# 62                10.1073/pnas.2200914119
# 64                10.1073/pnas.2200914119
# 66             10.1038/s41598-020-66092-9
# 67             10.1038/s41598-020-66092-9
# 68             10.1038/s41598-020-66092-9
# 69             10.1038/s41598-020-66092-9
# 70             10.1038/s41598-020-66092-9
# 71             10.1038/s41598-020-66092-9
# 243            10.1038/s41467-019-12780-8
# 309            10.1016/j.cell.2020.08.013
# 310            10.1016/j.cell.2020.08.013
# 368              10.15252/embj.2018100811
# 404                  10.2139/ssrn.3991078
# 406                  10.2139/ssrn.3991078
# 431               10.1126/science.abl4896
# 439               10.1126/science.aba7721
# 546             10.1038/s41586-020-2157-4
#
#                                        dataset_id
# soma_joinid
# 35           f8c77961-67a7-4161-b8c2-61c3f917b54f  \
# 36           e6dad530-418b-47f9-af6e-472e56a7b314
# 37           de17ac25-550a-4018-be75-bbb485a0636e
# 38           d95ab381-2b7c-4885-b168-0097ed4e397f
# 39           cec9f9a5-8832-437d-99af-fb8237cde54b
# 40           c3d381b2-3104-444e-8ad5-d3524407bbb6
# 41           ab5b2256-b209-48b5-a801-c5d9a8c0de56
# 42           9cfee1e6-b24f-433d-a269-f01841655d6a
# 43           4e38f019-f8e8-44ae-ad32-ba500de6f64c
# 44           389bfbb9-8ef1-4582-8c41-410131c3d0eb
# 62           9ff99bf8-2524-4ab5-ab6e-4bc218e4a449
# 64           489318a0-24c3-4f5c-b105-f084ed0ea026
# 66           d319af7f-be2e-441e-8caa-3b8a88480e89
# 67           bc7260e0-54cf-4b0b-823d-93f5b850f757
# 68           8623d55f-d91c-41c2-ae68-ed2072fd268d
# 69           7b75b2c4-6d99-40be-9a61-391455d859e6
# 70           5cdbb2ea-c622-466d-9ead-7884ad8cb99f
# 71           2f6a20f1-173d-4b8d-860b-c47ffea120fa
# 243          856c1b98-5727-49da-bf0f-151bdb8cb056
# 309          ccfdcad0-7104-46b9-addf-fd66a2a15907
# 310          babbf9f3-f482-45a5-ba76-c41f4c2f503e
# 368          d5c67a4e-a8d9-456d-a273-fa01adb1b308
# 404          0129dbd9-a7d3-4f6b-96b9-1da155a93748
# 406          aad97cb5-f375-45ef-ae9d-178e7f5d5180
# 431          53d208b0-2cfd-4366-9866-c3c6114081bc
# 439          f7c1c579-2dc0-47e2-ba19-8165c5a0e353
# 546          2adb1f8a-a6b1-4909-8ee8-484814e2d4bf
#
#                                                  dataset_title
# soma_joinid
# 35                                 Amacrine cells of human eye  \
# 36                                 All cell types of human eye
# 37                                  Myeloid cells of human eye
# 38                                     Cone cells of human eye
# 39                         Retinal ganglion cells of human eye
# 40                               Horizontal cells of human eye
# 41                             Non-neuronal cells of human eye
# 42               Retinal pigment epithelial cells of human eye
# 43                                  Bipolar cells of human eye
# 44                                      Rod cells of human eye
# 62                                             Integrated data
# 64                                                        Lens
# 66           Retinal ganglion cells of the human fovea and ...
# 67           Non-neuronal cells of the human fovea and peri...
# 68           Bipolar cells of the human fovea and periphera...
# 69           Photoreceptor cells of the human fovea and per...
# 70           Amacrine cells of the human fovea and peripher...
# 71           Horizontal cells of the human fovea and periph...
# 243                                                     Retina
# 309          Periphery - Cell Types of the Human Retina and...
# 310          Fovea - Cell Types of the Human Retina and Its...
# 368                                                     Retina
# 404                 All major cell types in adult human retina
# 406                     Retinal ganglion cells in human retina
# 431                                 Tabula Sapiens - All Cells
# 439                      Survey of human embryonic development
# 546          Construction of a human cell landscape at sing...
#
#                                      dataset_h5ad_path
# soma_joinid
# 35           f8c77961-67a7-4161-b8c2-61c3f917b54f.h5ad  \
# 36           e6dad530-418b-47f9-af6e-472e56a7b314.h5ad
# 37           de17ac25-550a-4018-be75-bbb485a0636e.h5ad
# 38           d95ab381-2b7c-4885-b168-0097ed4e397f.h5ad
# 39           cec9f9a5-8832-437d-99af-fb8237cde54b.h5ad
# 40           c3d381b2-3104-444e-8ad5-d3524407bbb6.h5ad
# 41           ab5b2256-b209-48b5-a801-c5d9a8c0de56.h5ad
# 42           9cfee1e6-b24f-433d-a269-f01841655d6a.h5ad
# 43           4e38f019-f8e8-44ae-ad32-ba500de6f64c.h5ad
# 44           389bfbb9-8ef1-4582-8c41-410131c3d0eb.h5ad
# 62           9ff99bf8-2524-4ab5-ab6e-4bc218e4a449.h5ad
# 64           489318a0-24c3-4f5c-b105-f084ed0ea026.h5ad
# 66           d319af7f-be2e-441e-8caa-3b8a88480e89.h5ad
# 67           bc7260e0-54cf-4b0b-823d-93f5b850f757.h5ad
# 68           8623d55f-d91c-41c2-ae68-ed2072fd268d.h5ad
# 69           7b75b2c4-6d99-40be-9a61-391455d859e6.h5ad
# 70           5cdbb2ea-c622-466d-9ead-7884ad8cb99f.h5ad
# 71           2f6a20f1-173d-4b8d-860b-c47ffea120fa.h5ad
# 243          856c1b98-5727-49da-bf0f-151bdb8cb056.h5ad
# 309          ccfdcad0-7104-46b9-addf-fd66a2a15907.h5ad
# 310          babbf9f3-f482-45a5-ba76-c41f4c2f503e.h5ad
# 368          d5c67a4e-a8d9-456d-a273-fa01adb1b308.h5ad
# 404          0129dbd9-a7d3-4f6b-96b9-1da155a93748.h5ad
# 406          aad97cb5-f375-45ef-ae9d-178e7f5d5180.h5ad
# 431          53d208b0-2cfd-4366-9866-c3c6114081bc.h5ad
# 439          f7c1c579-2dc0-47e2-ba19-8165c5a0e353.h5ad
# 546          2adb1f8a-a6b1-4909-8ee8-484814e2d4bf.h5ad
#
#              dataset_total_cell_count
# soma_joinid
# 35                               6101
# 36                             100055
# 37                                395
# 38                               1378
# 39                               1777
# 40                               1875
# 41                               8193
# 42                               1635
# 43                              16540
# 44                              62509
# 62                              42901
# 64                              13900
# 66                              11404
# 67                              22125
# 68                              25908
# 69                               9070
# 70                              13607
# 71                               2868
# 243                             20091
# 309                             34723
# 310                             19768
# 368                             19694
# 404                            244474
# 406                             11617
# 431                            483152
# 439                           4062980
# 546                            598266

# %%
with cellxgene_census.open_soma() as census:
	adata = cellxgene_census.get_anndata(
    	census, 
		organism="Homo sapiens", 
		obs_value_filter=  "tissue_general in ['eye'] "
        "and disease == 'normal' "
        "and is_primary_data == True"
	)
# Out:
# The "stable" Census version is not yet available. Using "latest" Census version instead.
# The "latest" release is currently 2023-05-08. Specify 'census_version="2023-05-08"' in future calls to open_soma() to ensure data consistency.

# %%
adata.write_h5ad('2023_05_08_census_eye_normal_primary.homo.h5ad')
